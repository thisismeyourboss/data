# %% [markdown]
# # Information Practices Project
# # Data Analysis Videogame Data set
# # BY BHARAT KUMAR SHARMA

# %% [markdown]
# # The Videogame Dataset
# Here.The Videogame Dataset is a time-series data with  information about the global sales of videogaems the different publisher the genre year the game was released in the platform the game was released for
#
# The data is in csv format. We will use pandas for the analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\dell\Documents\vgsalesGlobale.csv')

# %% [markdown]
# # Data

# %%
data
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# 12        13                        Pokemon Gold/Pokemon Silver       GB
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 15        16                                 Kinect Adventures!     X360
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 18        19                                  Super Mario World     SNES
# 19        20       Brain Age: Train Your Brain in Minutes a Day       DS
# 20        21                      Pokemon Diamond/Pokemon Pearl       DS
# 21        22                                   Super Mario Land       GB
# 22        23                                Super Mario Bros. 3      NES
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 25        26                      Pokemon Ruby/Pokemon Sapphire      GBA
# 26        27                        Pokemon Black/Pokemon White       DS
# 27        28        Brain Age 2: More Training in Minutes a Day       DS
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 29        30                     Call of Duty: Modern Warfare 3     X360
# ...      ...                                                ...      ...
# 16568  16571                                        XI Coliseum      PSP
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16571  16574         Grisaia no Kajitsu: La Fruit de la Grisaia      PSP
# 16572  16575                   Scarlett: Nichijou no Kyoukaisen      PS2
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16575  16578                              Neo Angelique Special      PSP
# 16576  16579                                  Rugby Challenge 3     XOne
# 16577  16580                                          Damnation       PC
# 16578  16581                      Outdoors Unleashed: Africa 3D      3DS
# 16579  16582                                  PGA European Tour      N64
# 16580  16583                                          Real Rode      PS2
# 16581  16584                                          Fit & Fun      Wii
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16584  16587                                   Bust-A-Move 3000       GC
# 16585  16588                                             Breach       PC
# 16586  16589                     Secret Files 2: Puritas Cordis       DS
# 16587  16590                           Mezase!! Tsuri Master DS       DS
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16583  1999.0        Action           Virgin Interactive      0.01      0.00
# 16584  2003.0        Puzzle                      Ubisoft      0.01      0.00
# 16585  2011.0       Shooter                    Destineer      0.01      0.00
# 16586  2009.0     Adventure                  Deep Silver      0.00      0.01
# 16587  2009.0        Sports                  Hudson Soft      0.00      0.00
# 16588  2008.0        Puzzle        Majesco Entertainment      0.01      0.00
# 16589  2016.0        Action              dramatic create      0.00      0.00
# 16590  2007.0  Role-Playing           Falcom Corporation      0.00      0.00
# 16591  2004.0     Adventure                      Ubisoft      0.01      0.00
# 16592  2008.0    Simulation                    Destineer      0.01      0.00
# 16593  2002.0      Platform                        Kemco      0.01      0.00
# 16594  2003.0       Shooter                   Infogrames      0.01      0.00
# 16595  2008.0        Racing                   Activision      0.00      0.00
# 16596  2010.0        Puzzle                     7G//AMES      0.00      0.01
# 16597  2003.0      Platform                      Wanadoo      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 1          6.81         0.77         40.24
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 4         10.22         1.00         31.37
# 5          4.22         0.58         30.26
# 6          6.50         2.90         30.01
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# 9          0.28         0.47         28.31
# 10         1.93         2.75         24.76
# 11         4.13         1.92         23.42
# 12         7.20         0.71         23.10
# 13         3.60         2.15         22.72
# 14         2.53         1.79         22.00
# 15         0.24         1.67         21.82
# 16         0.97         4.14         21.40
# 17         0.41        10.57         20.81
# 18         3.54         0.55         20.61
# 19         4.16         2.05         20.22
# 20         6.04         1.37         18.36
# 21         4.18         0.42         18.14
# 22         3.84         0.46         17.28
# 23         0.06         1.38         16.38
# 24         0.47         1.78         16.15
# 25         5.38         0.50         15.85
# 26         5.65         0.82         15.32
# 27         5.32         1.18         15.30
# 28         1.87         1.16         14.98
# 29         0.13         1.32         14.76
# ...         ...          ...           ...
# 16568      0.01         0.00          0.01
# 16569      0.00         0.00          0.01
# 16570      0.00         0.00          0.01
# 16571      0.01         0.00          0.01
# 16572      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16575      0.01         0.00          0.01
# 16576      0.00         0.00          0.01
# 16577      0.00         0.00          0.01
# 16578      0.00         0.00          0.01
# 16579      0.00         0.00          0.01
# 16580      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
# 16582      0.00         0.00          0.01
# 16583      0.00         0.00          0.01
# 16584      0.00         0.00          0.01
# 16585      0.00         0.00          0.01
# 16586      0.00         0.00          0.01
# 16587      0.01         0.00          0.01
# 16588      0.00         0.00          0.01
# 16589      0.01         0.00          0.01
# 16590      0.01         0.00          0.01
# 16591      0.00         0.00          0.01
# 16592      0.00         0.00          0.01
# 16593      0.00         0.00          0.01
# 16594      0.00         0.00          0.01
# 16595      0.00         0.00          0.01
# 16596      0.00         0.00          0.01
# 16597      0.00         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# # Data Exploration

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
data.shape
# Out:
# (16598, 11)

# %% [markdown]
# # So we have 16598 rows and 11 columns

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16598, step=1)

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
data['Name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Plushees', 'Woody Woodpecker in Crazy Castle 5', 'Know How 2'],
#       dtype=object)

# %%
data['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
data['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
data['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
#        'Imagic', 'Tecmo Koei', 'Valve Software', 'ASCII Entertainment',
#        'Mindscape', 'Infogrames', 'Unknown', 'Square', 'Valve',
#        'Activision Value', 'Banpresto', 'D3Publisher',
#        'Oxygen Interactive', 'Red Storm Entertainment', 'Video System',
#        'Hello Games', 'Global Star', 'Gotham Games', 'Westwood Studios',
#        'GungHo', 'Crave Entertainment', 'Hudson Soft', 'Coleco',
#        'Rising Star Games', 'Atlus', 'TDK Mediactive', 'ASC Games',
#        'Zoo Games', 'Accolade', 'Sony Online Entertainment', '3DO', 'RTL',
#        'Natsume', 'Focus Home Interactive', 'Alchemist',
#        'Black Label Games', 'SouthPeak Games', 'Mastertronic', 'Ocean',
#        'Zoo Digital Publishing', 'Psygnosis', 'City Interactive',
#        'Empire Interactive', 'Success', 'Compile', 'Russel', 'Taito',
#        'Agetec', 'GSP', 'Microprose', 'Play It', 'Slightly Mad Studios',
#        'Tomy Corporation', 'Sammy Corporation', 'Koch Media',
#        'Game Factory', 'Titus', 'Marvelous Entertainment', 'Genki',
#        'Mojang', 'Pinnacle', 'CTO SpA', 'TalonSoft', 'Crystal Dynamics',
#        'SCi', 'Quelle', 'mixi, Inc', 'Rage Software', 'Ubisoft Annecy',
#        'Scholastic Inc.', 'Interplay', 'Mystique', 'ChunSoft',
#        'Square EA', '20th Century Fox Video Games', 'Avanquest Software',
#        'Hudson Entertainment', 'Nordic Games', 'Men-A-Vision', 'Nobilis',
#        'Big Ben Interactive', 'Touchstone', 'Spike', 'Jester Interactive',
#        'Nippon Ichi Software', 'LEGO Media', 'Quest',
#        'Illusion Softworks', 'Tigervision', 'Funbox Media',
#        'Rocket Company', 'Metro 3D', 'Mattel Interactive', 'IE Institute',
#        'Rondomedia', 'Sony Computer Entertainment America',
#        'Universal Gamex', 'Ghostlight', 'Wizard Video Games',
#        'BMG Interactive Entertainment', 'PQube', 'Trion Worlds', 'Laguna',
#        'Ignition Entertainment', 'Takara', 'Kadokawa Shoten', 'Destineer',
#        'Enterbrain', 'Xseed Games', 'Imagineer',
#        'System 3 Arcade Software', 'CPG Products', 'Aruze Corp',
#        'Gamebridge', 'Midas Interactive Entertainment', 'Jaleco',
#        'Answer Software', 'XS Games', 'Activision Blizzard',
#        'Pack In Soft', 'Rebellion', 'Xplosiv', 'Ultravision',
#        'GameMill Entertainment', 'Wanadoo', 'NovaLogic', 'Telltale Games',
#        'Epoch', 'BAM! Entertainment', 'Knowledge Adventure', 'Mastiff',
#        'Tetris Online', 'Harmonix Music Systems', 'ESP', 'TYO',
#        'Telegames', 'Mud Duck Productions', 'Screenlife', 'Pioneer LDC',
#        'Magical Company', 'Mentor Interactive', 'Kemco',
#        'Human Entertainment', 'Avanquest', 'Data Age',
#        'Electronic Arts Victor', 'Black Bean Games', 'Jack of All Games',
#        '989 Sports', 'Takara Tomy', 'Media Rings', 'Elf', 'Kalypso Media',
#        'Starfish', 'Zushi Games', 'Jorudan', 'Destination Software, Inc',
#        'New', 'Brash Entertainment', 'ITT Family Games', 'PopCap Games',
#        'Home Entertainment Suppliers', 'Ackkstudios', 'Starpath Corp.',
#        'P2 Games', 'BPS', 'Gathering of Developers', 'NewKidCo',
#        'Storm City Games', 'CokeM Interactive', 'CBS Electronics',
#        'Magix', 'Marvelous Interactive', 'Nihon Falcom Corporation',
#        'Wargaming.net', 'Angel Studios', 'Arc System Works', 'Playmates',
#        'SNK Playmore', 'Hamster Corporation', 'From Software',
#        'Nippon Columbia', 'Nichibutsu', 'Little Orbit',
#        'Conspiracy Entertainment', 'DTP Entertainment', 'Hect',
#        'Mumbo Jumbo', 'Pacific Century Cyber Works', 'Indie Games',
#        'Liquid Games', 'NEC', 'Axela', 'ArtDink', 'Sunsoft', 'Gust',
#        'SNK', 'NEC Interchannel', 'FuRyu', 'Xing Entertainment',
#        'ValuSoft', 'Victor Interactive', 'Detn8 Games',
#        'American Softworks', 'Nordcurrent', 'Bomb', 'Falcom Corporation',
#        'AQ Interactive', 'CCP', 'Milestone S.r.l.', 'Sears',
#        'JoWood Productions', 'Seta Corporation', 'On Demand', 'NCS',
#        'Aspyr', 'Gremlin Interactive Ltd', 'Agatsuma Entertainment',
#        'Compile Heart', 'Culture Brain', 'Mad Catz', 'Shogakukan',
#        'Merscom LLC', 'Rebellion Developments', 'Nippon Telenet',
#        'TDK Core', 'bitComposer Games', 'Foreign Media Games', 'Astragon',
#        'SSI', 'Kadokawa Games', 'Idea Factory',
#        'Performance Designed Products', 'Asylum Entertainment',
#        'Core Design Ltd.', 'PlayV', 'UFO Interactive',
#        'Idea Factory International', 'Playlogic Game Factory',
#        'Essential Games', 'Adeline Software', 'Funcom',
#        'Panther Software', 'Blast! Entertainment Ltd', 'Game Life',
#        'DSI Games', 'Avalon Interactive', 'Popcorn Arcade',
#        'Neko Entertainment', 'Vir2L Studios', 'Aques', 'Syscom',
#        'White Park Bay Software', 'System 3', 'Vatical Entertainment',
#        'Daedalic', 'EA Games', 'Media Factory', 'Vic Tokai',
#        'The Adventure Company', 'Game Arts', 'Broccoli', 'Acquire',
#        'General Entertainment', 'Excalibur Publishing', 'Imadio',
#        'Swing! Entertainment', 'Sony Music Entertainment', 'Aqua Plus',
#        'Paradox Interactive', 'Hip Interactive',
#        'DreamCatcher Interactive', 'Tripwire Interactive', 'Sting',
#        'Yacht Club Games', 'SCS Software', 'Bigben Interactive',
#        'Havas Interactive', 'Slitherine Software', 'Graffiti', 'Funsta',
#        'Telstar', 'U.S. Gold', 'DreamWorks Interactive',
#        'Data Design Interactive', 'MTO', 'DHM Interactive', 'FunSoft',
#        'SPS', 'Bohemia Interactive', 'Reef Entertainment',
#        'Tru Blu Entertainment', 'Moss', 'T&E Soft', 'O-Games',
#        'Aksys Games', 'NDA Productions', 'Data East',
#        'Time Warner Interactive', 'Gainax Network Systems', 'Daito',
#        'O3 Entertainment', 'Gameloft', 'Xicat Interactive',
#        'Simon & Schuster Interactive', 'Valcon Games', 'PopTop Software',
#        'TOHO', 'HMH Interactive', '5pb', 'Cave',
#        'CDV Software Entertainment', 'Microids', 'PM Studios', 'Paon',
#        'Micro Cabin', 'GameTek', 'Benesse', 'Type-Moon',
#        'Enjoy Gaming ltd.', 'Asmik Corp', 'Interplay Productions',
#        'Asmik Ace Entertainment', 'inXile Entertainment', 'Image Epoch',
#        'Phantom EFX', 'Evolved Games', 'responDESIGN',
#        'Culture Publishers', 'Griffin International', 'Hackberry',
#        'Hearty Robin', 'Nippon Amuse', 'Origin Systems', 'Seventh Chord',
#        'Mitsui', 'Milestone', 'Abylight', 'Flight-Plan', 'Glams', 'Locus',
#        'Warp', 'Daedalic Entertainment', 'Alternative Software',
#        'Myelin Media', 'Mercury Games', 'Irem Software Engineering',
#        'Sunrise Interactive', 'Elite', 'Evolution Games', 'Tivola',
#        'Global A Entertainment', 'Edia', 'Athena', 'Aria', 'Gamecock',
#        'Tommo', 'Altron', 'Happinet', 'iWin', 'Media Works', 'Fortyfive',
#        'Revolution Software', 'Imax', 'Crimson Cow', '10TACLE Studios',
#        'Groove Games', 'Pack-In-Video', 'Insomniac Games',
#        'Ascaron Entertainment GmbH', 'Asgard', 'Ecole', 'Yumedia',
#        'Phenomedia', 'HAL Laboratory', 'Grand Prix Games', 'DigiCube',
#        'Creative Core', 'Kaga Create', 'WayForward Technologies',
#        'LSP Games', 'ASCII Media Works', 'Coconuts Japan', 'Arika',
#        'Ertain', 'Marvel Entertainment', 'Prototype',
#        'TopWare Interactive', 'Phantagram', '1C Company',
#        'The Learning Company', 'TechnoSoft', 'Vap', 'Misawa', 'Tradewest',
#        'Team17 Software', 'Yeti', 'Pow', 'Navarre Corp', 'MediaQuest',
#        'Max Five', 'Comfort', 'Monte Christo Multimedia', 'Pony Canyon',
#        'Riverhillsoft', 'Summitsoft', 'Milestone S.r.l', 'Playmore',
#        'MLB.com', 'Kool Kizz', 'Flashpoint Games', '49Games',
#        'Legacy Interactive', 'Alawar Entertainment', 'CyberFront',
#        'Cloud Imperium Games Corporation', 'Societa',
#        'Virtual Play Games', 'Interchannel', 'Sonnet', 'Experience Inc.',
#        'Zenrin', 'Iceberg Interactive', 'Ivolgamus', '2D Boy',
#        'MC2 Entertainment', 'Kando Games', 'Just Flight', 'Office Create',
#        'Mamba Games', 'Fields', 'Princess Soft', 'Maximum Family Games',
#        'Berkeley', 'Fuji', 'Dusenberry Martin Racing', 'imageepoch Inc.',
#        'Big Fish Games', 'Her Interactive', 'Kamui', 'ASK',
#        'Headup Games', 'KSS', 'Cygames', 'KID', 'Quinrose', 'Sunflowers',
#        'dramatic create', 'TGL', 'Encore', 'Extreme Entertainment Group',
#        'Intergrow', 'G.Rev', 'Sweets', 'Kokopeli Digital Studios',
#        'Number None', 'Nexon', 'id Software', 'BushiRoad', 'Tryfirst',
#        'Strategy First', '7G//AMES', 'GN Software', "Yuke's",
#        'Easy Interactive', 'Licensed 4U', 'FuRyu Corporation',
#        'Lexicon Entertainment', 'Paon Corporation', 'Kids Station', 'GOA',
#        'Graphsim Entertainment', 'King Records', 'Introversion Software',
#        'Minato Station', 'Devolver Digital', 'Blue Byte', 'Gaga',
#        'Yamasa Entertainment', 'Plenty', 'Views', 'fonfun', 'NetRevo',
#        'Codemasters Online', 'Quintet', 'Phoenix Games', 'Dorart',
#        'Marvelous Games', 'Focus Multimedia', 'Imageworks',
#        'Karin Entertainment', 'Aerosoft', 'Technos Japan Corporation',
#        'Gakken', 'Mirai Shounen', 'Datam Polystar', 'Saurus', 'HuneX',
#        'Revolution (Japan)', 'Giza10', 'Visco', 'Alvion', 'Mycom', 'Giga',
#        'Warashi', 'System Soft', 'Sold Out', 'Lighthouse Interactive',
#        'Masque Publishing', 'RED Entertainment', 'Michaelsoft',
#        'Media Entertainment', 'New World Computing', 'Genterprise',
#        'Interworks Unlimited, Inc.', 'Boost On', 'Stainless Games',
#        'EON Digital Entertainment', 'Epic Games', 'Naxat Soft',
#        'Ascaron Entertainment', 'Piacci', 'Nitroplus',
#        'Paradox Development', 'Otomate', 'Ongakukan', 'Commseed',
#        'Inti Creates', 'Takuyo', 'Interchannel-Holon', 'Rain Games',
#        'UIG Entertainment'], dtype=object)

# %%
data['NA_Sales'].nunique()
# Out:
# 409

# %%
data['EU_Sales'].nunique()
# Out:
# 305

# %%
data['JP_Sales'].nunique()
# Out:
# 244

# %%
data['Global_Sales'].nunique()
# Out:
# 623

# %%
data.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
data.count()
# Out:
# Rank            16598
# Name            16598
# Platform        16598
# Year            16327
# Genre           16598
# Publisher       16540
# NA_Sales        16598
# EU_Sales        16598
# JP_Sales        16598
# Other_Sales     16598
# Global_Sales    16598
# dtype: int64

# %%
data['Name'].value_counts()
# Out:
# Need for Speed: Most Wanted                                        12
# Madden NFL 07                                                       9
# Ratatouille                                                         9
# LEGO Marvel Super Heroes                                            9
# FIFA 14                                                             9
# Angry Birds Star Wars                                               8
# LEGO Harry Potter: Years 5-7                                        8
# Terraria                                                            8
# Cars                                                                8
# Madden NFL 08                                                       8
# The LEGO Movie Videogame                                            8
# FIFA Soccer 13                                                      8
# Monopoly                                                            8
# LEGO The Hobbit                                                     8
# FIFA 15                                                             8
# Lego Batman 3: Beyond Gotham                                        8
# LEGO Jurassic World                                                 8
# LEGO Star Wars II: The Original Trilogy                             8
# Harry Potter and the Order of the Phoenix                           7
# FIFA 12                                                             7
# Skylanders: Trap Team                                               7
# The Amazing Spider-Man 2 (2014)                                     7
# Harry Potter and the Sorcerer's Stone                               7
# Harry Potter and the Half-Blood Prince                              7
# Star Wars The Clone Wars: Republic Heroes                           7
# LEGO Marvel's Avengers                                              7
# Major League Baseball 2K11                                          7
# The Sims 2                                                          7
# Lego Star Wars: The Force Awakens                                   7
# Need For Speed: Undercover                                          7
#                                                                    ..
# Invizimals: The Lost Kingdom                                        1
# Jikandia: The Timeless Land                                         1
# Imagine: Animal Doctor                                              1
# Killzone 3                                                          1
# Famicom Mini: Adventure Island                                      1
# Beat City                                                           1
# Logic Machines                                                      1
# Doctor Lautrec and the Forgotten Knights                            1
# Sloane to MacHale no Nazo no Monogatari 2                           1
# Battle Dodge Ball                                                   1
# XGRA: Extreme G-Racing Association                                  1
# Race Driver: Create & Race                                          1
# Test Drive 5                                                        1
# Super Robot Taisen 64                                               1
# Bleach: Versus Crusade                                              1
# Junior Classic Books & Fairytales                                   1
# Sherlock Holmes and the Mystery of Osborne House                    1
# Bullet Witch                                                        1
# Hakuouki: Shinsengumi Kitan                                         1
# TERA                                                                1
# Spec Ops: Airborne Commando                                         1
# Brothers Conflict: Brilliant Blue                                   1
# Jinsei Game DS                                                      1
# Kirby 64: The Crystal Shards                                        1
# Saturday Night Slam Masters                                         1
# Medabots 9: Metabee / Rokusho                                       1
# Yu-Gi-Oh! 7 Trials to Glory: World Championship Tournament 2005     1
# Speedball 2100                                                      1
# Phantasy Star Universe: Ambition of the Illuminus                   1
# Star Fox Command                                                    1
# Name: Name, Length: 11493, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data1=data.drop(['Rank','NA_Sales','EU_Sales','JP_Sales','Other_Sales'],axis='columns')

# %%
#data.loc[~(data==0.00).all(axis=1)]
data2=data1.dropna()

# %%
data2.isnull().sum()
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# # Removing outliers

# %%
data3=data2[~(data1['Global_Sales']<1)]
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel
# 2076                                   Wheel of Fortune      Wii  2010.0
# 2077                                    Disney Infinity      PS3  2013.0
# 2078                                         Dark Souls     X360  2011.0
# 2079                                 Puzzler Collection       DS  2008.0
# 2080                                Jampack Winter 2000       PS  2000.0
#
#              Genre                               Publisher  Global_Sales
# 0           Sports                                Nintendo         82.74
# 1         Platform                                Nintendo         40.24
# 2           Racing                                Nintendo         35.82
# 3           Sports                                Nintendo         33.00
# 4     Role-Playing                                Nintendo         31.37
# 5           Puzzle                                Nintendo         30.26
# 6         Platform                                Nintendo         30.01
# 7             Misc                                Nintendo         29.02
# 8         Platform                                Nintendo         28.62
# 9          Shooter                                Nintendo         28.31
# 10      Simulation                                Nintendo         24.76
# 11          Racing                                Nintendo         23.42
# 12    Role-Playing                                Nintendo         23.10
# 13          Sports                                Nintendo         22.72
# 14          Sports                                Nintendo         22.00
# 15            Misc                  Microsoft Game Studios         21.82
# 16          Action                    Take-Two Interactive         21.40
# 17          Action                    Take-Two Interactive         20.81
# 18        Platform                                Nintendo         20.61
# 19            Misc                                Nintendo         20.22
# 20    Role-Playing                                Nintendo         18.36
# 21        Platform                                Nintendo         18.14
# 22        Platform                                Nintendo         17.28
# 23          Action                    Take-Two Interactive         16.38
# 24          Action                    Take-Two Interactive         16.15
# 25    Role-Playing                                Nintendo         15.85
# 26    Role-Playing                                Nintendo         15.32
# 27          Puzzle                                Nintendo         15.30
# 28          Racing             Sony Computer Entertainment         14.98
# 29         Shooter                              Activision         14.76
# ...            ...                                     ...           ...
# 2051        Action  Warner Bros. Interactive Entertainment          1.01
# 2052        Racing                             Codemasters          1.01
# 2053      Platform                                 Ubisoft          1.01
# 2054       Shooter                         Electronic Arts          1.00
# 2055        Racing                      Empire Interactive          1.00
# 2056  Role-Playing                                  Capcom          1.00
# 2057        Sports            Konami Digital Entertainment          1.00
# 2058      Fighting                              Tecmo Koei          1.00
# 2059       Shooter                                  Capcom          1.00
# 2060        Racing                                Nintendo          1.00
# 2061        Sports                                Nintendo          1.00
# 2062          Misc                                Nintendo          1.00
# 2063          Misc                       Sammy Corporation          1.00
# 2064      Fighting                      Namco Bandai Games          1.00
# 2065       Shooter                                 Ubisoft          1.00
# 2066        Action                                     THQ          1.00
# 2067        Sports            Konami Digital Entertainment          1.00
# 2068        Racing                         Electronic Arts          1.00
# 2069        Sports             Sony Computer Entertainment          1.00
# 2070       Shooter      Sony Computer Entertainment Europe          1.00
# 2071        Sports                         Electronic Arts          1.00
# 2072        Action                              Tecmo Koei          1.00
# 2073      Strategy                                     THQ          1.00
# 2074          Misc                                 Ubisoft          1.00
# 2075        Action                         Electronic Arts          1.00
# 2076          Misc                                     THQ          1.00
# 2077        Action              Disney Interactive Studios          1.00
# 2078  Role-Playing                      Namco Bandai Games          1.00
# 2079        Puzzle                                 Ubisoft          1.00
# 2080          Misc             Sony Computer Entertainment          1.00
#
# [2058 rows x 6 columns]

# %%
a=data3['Global_Sales']
print(a)
b=round(a)
c=b
print(c)
data4=data3.drop(['Global_Sales'],axis='columns')
data4['Global_sales']=c
data4
# Out:
# 0       82.74
# 21        Platform                                Nintendo          18.0
# 22        Platform                                Nintendo          17.0
# 23          Action                    Take-Two Interactive          16.0
# 24          Action                    Take-Two Interactive          16.0
# 25    Role-Playing                                Nintendo          16.0
# 26    Role-Playing                                Nintendo          15.0
# 27          Puzzle                                Nintendo          15.0
# 28          Racing             Sony Computer Entertainment          15.0
# 29         Shooter                              Activision          15.0
# ...            ...                                     ...           ...
# 2051        Action  Warner Bros. Interactive Entertainment           1.0
# 2052        Racing                             Codemasters           1.0
# 2053      Platform                                 Ubisoft           1.0
# 2054       Shooter                         Electronic Arts           1.0
# 2055        Racing                      Empire Interactive           1.0
# 2056  Role-Playing                                  Capcom           1.0
# 2057        Sports            Konami Digital Entertainment           1.0
# 2058      Fighting                              Tecmo Koei           1.0
# 2059       Shooter                                  Capcom           1.0
# 2060        Racing                                Nintendo           1.0
# 2061        Sports                                Nintendo           1.0
# 2062          Misc                                Nintendo           1.0
# 2063          Misc                       Sammy Corporation           1.0
# 2064      Fighting                      Namco Bandai Games           1.0
# 2065       Shooter                                 Ubisoft           1.0
# 2066        Action                                     THQ           1.0
# 2067        Sports            Konami Digital Entertainment           1.0
# 2068        Racing                         Electronic Arts           1.0
# 2069        Sports             Sony Computer Entertainment           1.0
# 2070       Shooter      Sony Computer Entertainment Europe           1.0
# 2071        Sports                         Electronic Arts           1.0
# 2072        Action                              Tecmo Koei           1.0
# 2073      Strategy                                     THQ           1.0
# 2074          Misc                                 Ubisoft           1.0
# 2075        Action                         Electronic Arts           1.0
# 2076          Misc                                     THQ           1.0
# 2077        Action              Disney Interactive Studios           1.0
# 2078  Role-Playing                      Namco Bandai Games           1.0
# 2079        Puzzle                                 Ubisoft           1.0
# 2080          Misc             Sony Computer Entertainment           1.0
#
# [2058 rows x 6 columns]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Questions 🙋
# 1. Which publisher has made most games.
# 2. Which is the most used platform .
# 3. In which Year maximum games were made.
# 4. Which platform was most used in which year.
# 5. Which year could be said the games manufacturing year.
# 6. Which genere is the most popular
# 7. Which deacde which genre was popular
# 8. Biggest game publisher
# 9. Which deacde which genre was popular based on sales
# 10. Most sold genre
# 11. Most famous genre based on global sales.

# %% [markdown]
# question 1. Which publisher has made most games?

# %%
data4['Publisher'].value_counts().max()
# Out:
# 338

# %%
data4['Publisher'].value_counts()
# Out:
# Nintendo                                  338
# Electronic Arts                           337
# Activision                                159
# Sony Computer Entertainment               149
# Ubisoft                                   117
# Take-Two Interactive                       91
# THQ                                        88
# Sega                                       74
# Konami Digital Entertainment               61
# Capcom                                     60
# Microsoft Game Studios                     54
# Namco Bandai Games                         53
# Warner Bros. Interactive Entertainment     41
# Square Enix                                41
# Atari                                      39
# Disney Interactive Studios                 35
# LucasArts                                  32
# Eidos Interactive                          26
# Bethesda Softworks                         22
# SquareSoft                                 19
# Acclaim Entertainment                      18
# Midway Games                               16
# Codemasters                                12
# Virgin Interactive                         12
# Vivendi Games                              11
# Enix Corporation                           11
# Sony Computer Entertainment Europe          8
# 505 Games                                   7
# 989 Studios                                 6
# Hasbro Interactive                          6
#                                          ...
# Mastertronic                                1
# Zoo Games                                   1
# Gotham Games                                1
# SouthPeak Games                             1
# Tomy Corporation                            1
# ASC Games                                   1
# Zoo Digital Publishing                      1
# NCSoft                                      1
# Slightly Mad Studios                        1
# Sammy Corporation                           1
# Activision Value                            1
# Black Label Games                           1
# RTL                                         1
# Square                                      1
# Oxygen Interactive                          1
# City Interactive                            1
# 3DO                                         1
# Unknown                                     1
# Rising Star Games                           1
# Accolade                                    1
# Taito                                       1
# Russel                                      1
# Crave Entertainment                         1
# Hello Games                                 1
# Natsume                                     1
# Red Storm Entertainment                     1
# Parker Bros.                                1
# Global Star                                 1
# Play It                                     1
# GungHo                                      1
# Name: Publisher, Length: 100, dtype: int64

# %% [markdown]
# # Hence Nintendo has made most games

# %% [markdown]
# Question 2.Which is the most used platform ?

# %%
data4['Platform'].value_counts().max()
# Out:
# 320

# %%
data4['Platform'].value_counts()
# Out:
# PS2     320
# PS3     246
# X360    235
# PS      204
# Wii     157
# DS      144
# NES      74
# PS4      73
# PC       68
# GBA      68
# PSP      56
# GB       54
# XB       53
# N64      51
# SNES     48
# 3DS      47
# GC       46
# XOne     43
# 2600     23
# WiiU     19
# GEN      11
# PSV       8
# DC        6
# SAT       3
# SCD       1
# Name: Platform, dtype: int64

# %% [markdown]
# # Hence PS2 is the most used platform.

# %% [markdown]
# Question 3. In which Year maximum games were made?

# %%
data4['Year'].value_counts().max()
# Out:
# 165

# %%
data4['Year'].value_counts()
# Out:
# 2008.0    165
# 2007.0    147
# 2010.0    126
# 2009.0    117
# 2011.0    111
# 2004.0    104
# 2003.0     99
# 2002.0     97
# 2006.0     94
# 2013.0     91
# 2005.0     91
# 2001.0     85
# 2014.0     83
# 2012.0     81
# 1998.0     79
# 2015.0     62
# 1997.0     59
# 1999.0     58
# 2000.0     54
# 1996.0     43
# 1994.0     21
# 1995.0     21
# 1992.0     19
# 1986.0     17
# 1993.0     15
# 2016.0     15
# 1990.0     14
# 1989.0     13
# 1988.0     11
# 1981.0     11
# 1984.0     11
# 1991.0     11
# 1985.0      8
# 1987.0      7
# 1982.0      7
# 1983.0      7
# 1980.0      4
# Name: Year, dtype: int64

# %% [markdown]
# # Maximum games were made in 2008

# %% [markdown]
# Question 5. Which genre is most popular.

# %%
data4['Genre'].value_counts().max()
# Out:
# 419

# %%
data4['Genre'].value_counts()
# Out:
# Action          419
# Sports          300
# Shooter         249
# Role-Playing    203
# Platform        194
# Racing          181
# Misc            168
# Fighting        123
# Simulation       93
# Puzzle           56
# Adventure        40
# Strategy         32
# Name: Genre, dtype: int64

# %% [markdown]
# # Hence Action Genre is the most popular

# %% [markdown]
# # Data Visulization

# %% [markdown]
# # using matplotlib for visulization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data4.boxplot()

# %%
data4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0570B790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0663B4B0>]],
#       dtype=object)

# %%
sns.pairplot(data4)

# %%
grp=data4.groupby('Genre')
x=grp['Global_sales'].agg(np.sum)
x
# Out:
# Genre
# Action          1044.0
# Adventure         86.0
# Fighting         264.0
# Misc             461.0
# Platform         648.0
# Puzzle           156.0
# Racing           475.0
# Role-Playing     622.0
# Shooter          758.0
# Simulation       226.0
# Sports           777.0
# Strategy          67.0
# Name: Global_sales, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(x, "ro" ,color='r')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.plot(x,"r--",color='g')
plt.xticks(rotation=90)
plt.title("Genre wise Global sales")
plt.xlabel('Genre')
plt.ylabel('Gllobal sales in lakhs')
plt.show()

# %%
grp=data4.groupby('Publisher')
y=grp['Global_sales'].agg(np.sum)
y
# Out:
# Publisher
# 3DO                                         1.0
# 505 Games                                  25.0
# 989 Studios                                10.0
# ASC Games                                   1.0
# ASCII Entertainment                         5.0
# Acclaim Entertainment                      26.0
# Accolade                                    1.0
# Activision                                480.0
# Activision Value                            2.0
# Agetec                                      1.0
# Alchemist                                   1.0
# Arena Entertainment                         5.0
# Atari                                      73.0
# Atlus                                       1.0
# Banpresto                                   2.0
# Bethesda Softworks                         66.0
# Black Label Games                           1.0
# Capcom                                    123.0
# City Interactive                            1.0
# Codemasters                                15.0
# Coleco                                      1.0
# Compile                                     1.0
# Crave Entertainment                         2.0
# D3Publisher                                 4.0
# Deep Silver                                 8.0
# Disney Interactive Studios                 54.0
# Eidos Interactive                          58.0
# Electronic Arts                           715.0
# Empire Interactive                          2.0
# Enix Corporation                           27.0
#                                           ...
# Sammy Corporation                           1.0
# Sega                                      140.0
# Slightly Mad Studios                        1.0
# Sony Computer Entertainment               435.0
# Sony Computer Entertainment Europe         22.0
# Sony Online Entertainment                   1.0
# SouthPeak Games                             1.0
# Square                                      2.0
# Square Enix                                81.0
# SquareSoft                                 39.0
# Success                                     1.0
# TDK Mediactive                              2.0
# THQ                                       149.0
# Taito                                       1.0
# Take-Two Interactive                      302.0
# Tecmo Koei                                  7.0
# Tomy Corporation                            1.0
# UEP Systems                                 2.0
# Ubisoft                                   262.0
# Universal Interactive                      11.0
# Unknown                                     2.0
# Valve                                       2.0
# Valve Software                              2.0
# Video System                                2.0
# Virgin Interactive                         32.0
# Vivendi Games                              23.0
# Warner Bros. Interactive Entertainment     78.0
# Westwood Studios                            2.0
# Zoo Digital Publishing                      1.0
# Zoo Games                                   1.0
# Name: Global_sales, Length: 100, dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.plot(y, "ro" ,color='r')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.plot(y,"r--",color='b')
plt.xticks(rotation=90)
plt.title("Publisher wise Global sales")
plt.xlabel('Publisher')
plt.ylabel('Global sales in lakhs')
plt.show()

# %%
grp=data4.groupby('Platform')
z=grp['Global_sales'].agg(np.sum)
z
# Out:
# Platform
# 2600     45.0
# 3DS     158.0
# DC        8.0
# DS      472.0
# GB      234.0
# GBA     150.0
# GC       95.0
# GEN      27.0
# N64     142.0
# NES     234.0
# PC      151.0
# PS      457.0
# PS2     768.0
# PS3     623.0
# PS4     222.0
# PSP     108.0
# PSV      11.0
# SAT       4.0
# SCD       2.0
# SNES    144.0
# Wii     627.0
# WiiU     50.0
# X360    671.0
# XB       87.0
# XOne     94.0
# Name: Global_sales, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.plot(z, "ro" ,color='r')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
m=data4['Platform']
g=data4['Global_sales']
sns.pointplot(m,g,color='violet')

plt.ylabel('Global Sales in lakhs')
plt.xlabel('Publisher')
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(15,6))
m=data4['Year']
g=data4['Global_sales']
sns.jointplot(m,g,color='g')

plt.ylabel('Global Sales in lakhs')
plt.xlabel('Year')
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(15,6))
plt.plot(z,"r--",color='b')
plt.xticks(rotation=90)
plt.title("PLatform wise Global sales")
plt.xlabel('Platform')
plt.ylabel('Global sales in lakhs')
plt.show()

# %%
plt.figure(figsize=(15,6))
m=data4['Platform']
g=data4['Global_sales']
plt.bar(m,g,color='g')
plt.xticks(m)
plt.ylabel('Global Sales in lakhs')
plt.xlabel('Platform')
plt.show()

# %%
plt.figure(figsize=(15,6))
m=data4['Genre']
g=data4['Year']
sns.violinplot(m,g,color='red')

plt.ylabel('Global Sales in lakhs')
plt.xlabel('Publisher')
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(15,6))
m=data4['Genre']
g=data4['Global_sales']
plt.bar(m,g,color='g')
plt.xticks(m)
plt.ylabel('Global Sales in lakhs')
plt.xlabel('Genre')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data4.corr(),annot=True,linewidth=0.5,cmap='Blues')

# %%
plt.figure(figsize=(15,6))
m=data4['Platform']
g=data4['Global_sales']
sns.stripplot(m,g,color='violet')

plt.ylabel('Global Sales in lakhs')
plt.xlabel('Publisher')
plt.show()

# %%
import pyfiglet
a=pyfiglet.figlet_format("COMPLETE")
print(a)
# Out:
#   ____ ___  __  __ ____  _     _____ _____ _____
#  / ___/ _ \|  \/  |  _ \| |   | ____|_   _| ____|
# | |  | | | | |\/| | |_) | |   |  _|   | | |  _|
# | |__| |_| | |  | |  __/| |___| |___  | | | |___
#  \____\___/|_|  |_|_|   |_____|_____| |_| |_____|

# %%
import pyfiglet
a=pyfiglet.figlet_format("BY \n BHARAT \n KUMAR \n SHARMA")
print(a)
# Out:
#  ______   __
# | __ ) \ / /
# |  _ \\ V /
# | |_) || |
# |____/ |_|
#
#   ____  _   _    _    ____      _  _____
#  | __ )| | | |  / \  |  _ \    / \|_   _|
#  |  _ \| |_| | / _ \ | |_) |  / _ \ | |
#  | |_) |  _  |/ ___ \|  _ <  / ___ \| |
#  |____/|_| |_/_/   \_\_| \_\/_/   \_\_|
#
#   _  ___   _ __  __    _    ____
#  | |/ / | | |  \/  |  / \  |  _ \
#  | ' /| | | | |\/| | / _ \ | |_) |
#  | . \| |_| | |  | |/ ___ \|  _ <
#  |_|\_\\___/|_|  |_/_/   \_\_| \_\
#
#   ____  _   _    _    ____  __  __    _
#  / ___|| | | |  / \  |  _ \|  \/  |  / \
#  \___ \| |_| | / _ \ | |_) | |\/| | / _ \
#   ___) |  _  |/ ___ \|  _ <| |  | |/ ___ \
#  |____/|_| |_/_/   \_\_| \_\_|  |_/_/   \_\

# %% [markdown]
# # Source of Data - Dataworld
